# %% [markdown]
# <a href="https://colab.research.google.com/github/patilhumesh88-spec/RBI-Policy-Sentiment-_Market-Movement-Predictor/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pdfminer.six transformers torch pandas yfinance matplotlib seaborn scipy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 39.4 MB/s eta 0:00:00
# ...
